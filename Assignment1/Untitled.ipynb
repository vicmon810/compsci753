# %%
import numpy as np

# %%
A = np.array([[1,2], [2,-0.3]])

E,V = np.linalg.eig(A)
print(E)
print(V)
# Out:
# [ 2.45297408 -1.75297408]
# [[ 0.80903834 -0.58775587]
#  [ 0.58775587  0.80903834]]

# %%
x = np.array([0.2,1])
N = 20 

for i in range(N):
    eigenValue = max(x)
    x = np.dot(A,x)/eigenValue
    print(eigenValue)
# Out:
# 1.0
# 2.2
# 1.9863636363636363
# 2.5491990846681922
# 1.9060412926391384
# 2.8532823442422988
# 1.9859274469089507
# 2.865235193608331
# 2.200749400814388
# 2.6538798912810266
# 2.320269257145768
# 2.553233191258827
# 2.384139159212465
# 2.503585995970297
# 2.417536368601343
# 2.4786702429166554
# 2.4348011548886723
# 2.4660579761785972
# 2.4436735233059195
# 2.459645860623293
